# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,3,1.5,4,2.5,6,4,3,5.5,5,2]
y = [3,4,8,4.5,10,5,15,9,5,16,13,3]

plt.scatter(x,y)
plt.title('Scatter Plot of the data')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
x = [1,2,3,1.5,4,2.5,6,4,3,5.5,5,2]
y = [3,4,8,4.5,10,5,15,9,5,16,13,3]

plt.scatter(x,y)
plt.title('Scatter Plot of the data')
plt.xlabel('X')
plt.ylabel('Y')

linear_model=np.polyfit(x,y,1)
linear_model_fn=np.poly1d(linear_model)
x_s=np.arange(0,7)
plt.plot(x_s,linear_model_fn(x_s),color='green')

plt.show()

# %%
x = [1,2,3,1.5,4,2.5,6,4,3,5.5,5,2]
y = [3,4,8,4.5,10,5,15,9,5,16,13,3]

plt.scatter(x,y)
plt.title('Scatter Plot of the data')
plt.xlabel('X')
plt.ylabel('Y')

linear_model=np.polyfit(x,y,2)
linear_model_fn=np.poly1d(linear_model)
x_s=np.arange(0,7)
plt.plot(x_s,linear_model_fn(x_s),color='green')

plt.show()

# %%
M = [0.6897, 1.0479, 0.8876, 0.949, 1.528, 0.820, 0.944, 1.210, 0.841,
     0.20255, 1.0208,0.8094, 0.249, 0.378, 0.5423, 0.1951, 0.975, 0.262]
R = [0.6489, 1.1618, 1.0284, 1.757, 1.734, 0.7761, 0.833, 1.7903, 0.762,
     0.22623, 1.0927, 0.7861, 0.2724, 0.408, 0.484, 0.2150, 0.9663, 0.276]
T = [4450.0, 5913.0, 5606.0, 5640.0, 6407.0, 4700.0, 5527.0, 6210.0, 5100.0,
     3311.0, 5867.0, 5202.0, 3325.0, 3561.0, 3463.0, 3226.0, 5770.0, 3585.0]

# %%
plt.scatter(M,R)
plt.title('Scatter Plot of the data')
plt.xlim(0,2)
plt.ylim(0,2.5)
plt.xlabel('M')
plt.ylabel('R')

linear_model=np.polyfit(M,R,1)
linear_model_fn=np.poly1d(linear_model)
x_s=np.arange(0,7)
plt.plot(x_s,linear_model_fn(x_s),color='green')

plt.show()

# %%
plt.scatter(M,T)
plt.title('Scatter Plot of the data')
plt.xlim(0,1.5)
plt.ylim(2000,7000)
plt.xlabel('M')
plt.ylabel('T')
linear_model=np.polyfit(M,T,1)
print(linear_model)
linear_model_fn=np.poly1d(linear_model)
x_s=np.arange(0,7)
plt.plot(x_s,linear_model_fn(x_s),color='green')
plt.show()
# Out:
# [2879.14300776 2658.15141121]

# %% [markdown]
# ## python 曲线拟合

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## 多项式拟合

# %%
from numpy import polyfit, poly1d

# %%
M = [0.6897, 1.0479, 0.8876, 0.949, 1.528, 0.820, 0.944, 1.210, 0.841,
     0.20255, 1.0208,0.8094, 0.249, 0.378, 0.5423, 0.1951, 0.975, 0.262]
R = [0.6489, 1.1618, 1.0284, 1.757, 1.734, 0.7761, 0.833, 1.7903, 0.762,
     0.22623, 1.0927, 0.7861, 0.2724, 0.408, 0.484, 0.2150, 0.9663, 0.276]
T = [4450.0, 5913.0, 5606.0, 5640.0, 6407.0, 4700.0, 5527.0, 6210.0, 5100.0,
     3311.0, 5867.0, 5202.0, 3325.0, 3561.0, 3463.0, 3226.0, 5770.0, 3585.0]

# %%
plt.scatter(M,R)
plt.title('Mass and Radius')
plt.xlim(0,2)
plt.ylim(0,2.5)
plt.xlabel('M')
plt.ylabel('R')
coeff1=np.polyfit(M,R,1)
print(coeff1)
linear_model_fn=np.poly1d(coeff1)
x_s=np.arange(0,7)
plt.plot(x_s,linear_model_fn(x_s),color='green')
plt.show()
# Out:
# [ 1.2399632  -0.08805251]

# %%
plt.scatter(M,T)
plt.title('Mass and Effective temperature')
plt.xlim(0,1.5)
plt.ylim(2000,7000)
plt.xlabel('M')
plt.ylabel('T')
coeff2=np.polyfit(M,T,1)
print(coeff2)
linear_model_fn=np.poly1d(coeff2)
x_s=np.arange(0,7)
plt.plot(x_s,linear_model_fn(x_s),color='green')
plt.show()
# Out:
# [2879.14300776 2658.15141121]

# %% [markdown]
# ## 最小二乘

# %%
from scipy.linalg import lstsq
from scipy.stats import linregress
