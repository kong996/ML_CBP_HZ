# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('habitable_dataset.csv')
df
# Out:
#           m1    m2      r1      r2         t1         t2        L1        L2  \
# 0       0.67  0.33  0.7408  0.3192  4587.1738  3608.2662  0.214719  0.015262
# 1       0.69  0.31  0.7656  0.2944  4644.7566  3550.6834  0.241070  0.012173
# 2       0.71  0.29  0.7904  0.2696  4702.3394  3493.1006  0.269922  0.009563
# 3       0.63  0.37  0.6912  0.3688  4472.0082  3723.4318  0.168852  0.023102
# 4       0.53  0.47  0.5672  0.4928  4184.0942  4011.3458  0.087130  0.055564
# ...      ...   ...     ...     ...        ...        ...       ...       ...
# 326687  0.78  0.22  0.8772  0.1828  4903.8792  3291.5608  0.393228  0.003466
# 326688  0.77  0.23  0.8648  0.1952  4875.0878  3320.3522  0.373292  0.004092
# 326689  0.80  0.20  0.9020  0.1580  4961.4620  3233.9780  0.435652  0.002413
# 326690  0.78  0.22  0.8772  0.1828  4903.8792  3291.5608  0.393228  0.003466
# 326691  0.58  0.42  0.6292  0.4308  4328.0512  3867.3888  0.122754  0.036687
#
# ...

# %%
train_dataset = df[:300000]
test_dataset = df[300000:]

# %%
train_dataset
# Out:
#           m1    m2      r1      r2         t1         t2        L1        L2  \
# 0       0.67  0.33  0.7408  0.3192  4587.1738  3608.2662  0.214719  0.015262
# 1       0.69  0.31  0.7656  0.2944  4644.7566  3550.6834  0.241070  0.012173
# 2       0.71  0.29  0.7904  0.2696  4702.3394  3493.1006  0.269922  0.009563
# 3       0.63  0.37  0.6912  0.3688  4472.0082  3723.4318  0.168852  0.023102
# 4       0.53  0.47  0.5672  0.4928  4184.0942  4011.3458  0.087130  0.055564
# ...      ...   ...     ...     ...        ...        ...       ...       ...
# 299995  0.65  0.35  0.7160  0.3440  4529.5910  3665.8490  0.190700  0.018884
# 299996  0.56  0.44  0.6044  0.4556  4270.4684  3924.9716  0.107359  0.043531
# 299997  0.79  0.21  0.8896  0.1704  4932.6706  3262.7694  0.414005  0.002908
# 299998  0.54  0.46  0.5796  0.4804  4212.8856  3982.5544  0.093511  0.051303
# 299999  0.78  0.22  0.8772  0.1828  4903.8792  3291.5608  0.393228  0.003466
#
# ...

# %%
train_dataset.to_csv('train_dataset.csv',index=False)

# %%
test_dataset
# Out:
#           m1    m2      r1      r2         t1         t2        L1        L2  \
# 300000  0.54  0.46  0.5796  0.4804  4212.8856  3982.5544  0.093511  0.051303
# 300001  0.56  0.44  0.6044  0.4556  4270.4684  3924.9716  0.107359  0.043531
# 300002  0.68  0.32  0.7532  0.3068  4615.9652  3579.4748  0.227593  0.013655
# 300003  0.79  0.21  0.8896  0.1704  4932.6706  3262.7694  0.414005  0.002908
# 300004  0.70  0.30  0.7780  0.2820  4673.5480  3521.8920  0.255173  0.010812
# ...      ...   ...     ...     ...        ...        ...       ...       ...
# 326687  0.78  0.22  0.8772  0.1828  4903.8792  3291.5608  0.393228  0.003466
# 326688  0.77  0.23  0.8648  0.1952  4875.0878  3320.3522  0.373292  0.004092
# 326689  0.80  0.20  0.9020  0.1580  4961.4620  3233.9780  0.435652  0.002413
# 326690  0.78  0.22  0.8772  0.1828  4903.8792  3291.5608  0.393228  0.003466
# 326691  0.58  0.42  0.6292  0.4308  4328.0512  3867.3888  0.122754  0.036687
#
# ...

# %%
test_dataset.to_csv('test_dataset.csv', index=False)
